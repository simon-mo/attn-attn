# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
data = [
    0.5342075256556442,
    0.6322690992018244,
    0.6465222348916762,
    0.6522234891676169,
    0.6237172177879133,
    0.6584948688711516,
    0.6704675028506272
]

# %%
plt.figure(figsize=(8,6))
plt.plot(np.arange(1, len(data)+1), data)
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.axvspan(0,1,alpha=0.3, color='gold', label='FC')
plt.axvspan(1,4,alpha=0.3, color='cyan', label='Attn')
plt.axvspan(4,5,alpha=0.3, color='green', label='Batch Norm')
plt.axvspan(5,6,alpha=0.3, color='gold', label='FC')
plt.axvspan(6,7,alpha=0.3, color='cyan', label='Attn')
plt.legend()
plt.title("Iterative Training")
plt.savefig('../imgs/iter.png')
